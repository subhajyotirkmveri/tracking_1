# %%
#!pip install ultralytics

# %%
import ultralytics
ultralytics.__version__
# Out:
# '8.1.35'

# %%
import cv2
import pandas as pd
from ultralytics import YOLO
from tracker import*

model=YOLO('yolov8s.pt')

# %%
class_list = ['person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus', 'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'stop sign', 'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep', 'cow', 'elephant', 'bear', 'zebra', 'giraffe', 'backpack', 'umbrella', 'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball', 'kite', 'baseball bat', 'baseball glove', 'skateboard', 'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 'cake', 'chair', 'couch', 'potted plant', 'bed', 'dining table', 'toilet', 'tv', 'laptop', 'mouse', 'remote', 'keyboard', 'cell phone', 'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'book', 'clock', 'vase', 'scissors', 'teddy bear', 'hair drier', 'toothbrush']

# %%
tracker=Tracker()
count=0

# %%
cap=cv2.VideoCapture('highway_mini.mp4')

# %%
down={}
up={}

counter_down=[]
counter_up=[]

# %% [raw]
# import cv2
#
# cap = cv2.VideoCapture('highway_mini.mp4')
# count = 0
#
# while True:
#     ret, frame = cap.read()
#     if not ret:
#         break
#
#     count += 1
#     frame = cv2.resize(frame, (1020, 500))
#
#     if count == 1:  # Check if it's the first frame
#         cv2.imwrite('first_frame.jpg', frame)  # Save the first frame as 'first_frame.jpg'
#
#     # Rest of your code...
#     # (Don't forget to indent the remaining code properly)
#
# cap.release()
# cv2.destroyAllWindows()

# %% [raw]
# while True:
#     ret,frame = cap.read()
#     if not ret:
#         break
#     count += 1
#     frame=cv2.resize(frame,(1020,500))
#
#
#     results=model.predict(frame)
#  #   print(results)
#     a=results[0].boxes.data
#     a = a.detach().cpu().numpy()  # added this line
#     px=pd.DataFrame(a).astype("float")
#     print(px)
#
#     list=[]
#
#     for index,row in px.iterrows():
# #        print(row)
#         x1=int(row[0])
#         y1=int(row[1])
#         x2=int(row[2])
#         y2=int(row[3])
#         d=int(row[5])
#         c=class_list[d]
#         if 'car' in c or 'truck' in c:
#             list.append([x1,y1,x2,y2])
#             #print(c)
#
#
#     cv2.imshow("frames", frame)
#     if cv2.waitKey(1)&0xFF==27:
#         break
# cap.release()
# cv2.destroyAllWindows()

# %%
while True:    
    ret,frame = cap.read()
    if not ret:
        break
    count += 1
    frame=cv2.resize(frame,(1020,500))
   

    results=model.predict(frame)
 #   print(results)
    a=results[0].boxes.data
    a = a.detach().cpu().numpy()  # added this line
    px=pd.DataFrame(a).astype("float")
    #print(px)

    list=[]
             
    for index,row in px.iterrows():
#        print(row) 
        x1=int(row[0])
        y1=int(row[1])
        x2=int(row[2])
        y2=int(row[3])
        d=int(row[5])
        c=class_list[d]
        if 'car' in c:
            list.append([x1,y1,x2,y2])
            #print(c)

    car_bbox_id=tracker.update(list)
    #print(bbox_id)
    for bbox in car_bbox_id:
        x3,y3,x4,y4,id=bbox
        cx=int(x3+x4)//2
        cy=int(y3+y4)//2

        red_line_y=198
        blue_line_y=268   
        offset = 7
        
  

        ''' both lines combined condition . First condition is for red line'''
        ## condition for counting the cars which are entering from red line and exiting from blue line
        if red_line_y < (cy + offset) and red_line_y > (cy - offset):
          down[id]=cy   
        if id in down:
           if blue_line_y < (cy + offset) and blue_line_y > (cy - offset):         
             cv2.circle(frame,(cx,cy),4,(0,0,255),-1)
             cv2.putText(frame,str(id),(cx,cy),cv2.FONT_HERSHEY_COMPLEX,0.8,(0,255,255),2)
             #counter+=1
             counter_down.append(id)  # get a list of the cars and buses which are entering the line red and exiting the line blue

        # condition for cars entering from  blue line
        if blue_line_y < (cy + offset) and blue_line_y > (cy - offset):
          up[id]=cy   
        if id in up:
           if red_line_y < (cy + offset) and red_line_y > (cy - offset):         
             cv2.circle(frame,(cx,cy),4,(0,0,255),-1)
             cv2.putText(frame,str(id),(cx,cy),cv2.FONT_HERSHEY_COMPLEX,0.8,(0,255,255),2)
             #counter+=1
             counter_up.append(id)  # get a list of the cars which are entering the line 1 and exiting the line 2 




    
    text_color = (255,255,255)  # white color for text
    red_color = (0, 0, 255)  # (B, G, R)   
    blue_color = (255, 0, 0)  # (B, G, R)
    green_color = (0, 255, 0)  # (B, G, R)  

    cv2.line(frame,(172,198),(774,198),red_color,3)  #  starting cordinates and end of line cordinates
    cv2.putText(frame,('red line'),(172,198),cv2.FONT_HERSHEY_SIMPLEX, 0.5, text_color, 1, cv2.LINE_AA)
    
    cv2.line(frame,(8,268),(927,268),blue_color,3)  # seconde line
    cv2.putText(frame,('blue line'),(8,268),cv2.FONT_HERSHEY_SIMPLEX, 0.5, text_color, 1, cv2.LINE_AA)    


    downwards = (len(counter_down))
    cv2.putText(frame,('going down - ')+ str(downwards),(60,40),cv2.FONT_HERSHEY_SIMPLEX, 0.5, green_color, 1, cv2.LINE_AA)    

    
    upwards = (len(counter_up))
    cv2.putText(frame,('going up - ')+ str(upwards),(60,60),cv2.FONT_HERSHEY_SIMPLEX, 0.5, text_color, 1, cv2.LINE_AA)  

    cv2.imshow("frames", frame)
    if cv2.waitKey(1)&0xFF==27:
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 320x640 9 cars, 3 trucks, 65.2ms
# Speed: 2.4ms preprocess, 65.2ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 76.7ms
# Speed: 1.5ms preprocess, 76.7ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 74.4ms
# Speed: 1.4ms preprocess, 74.4ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 70.6ms
# Speed: 1.2ms preprocess, 70.6ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 60.5ms
# Speed: 1.5ms preprocess, 60.5ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 66.8ms
# Speed: 1.3ms preprocess, 66.8ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 69.8ms
# Speed: 1.4ms preprocess, 69.8ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 65.2ms
# Speed: 1.3ms preprocess, 65.2ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 65.7ms
# Speed: 1.4ms preprocess, 65.7ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 64.8ms
# Speed: 1.7ms preprocess, 64.8ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 73.8ms
# Speed: 1.7ms preprocess, 73.8ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 68.2ms
# Speed: 1.4ms preprocess, 68.2ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 73.2ms
# Speed: 1.4ms preprocess, 73.2ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 58.9ms
# Speed: 1.3ms preprocess, 58.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 58.5ms
# Speed: 1.6ms preprocess, 58.5ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 59.5ms
# Speed: 1.7ms preprocess, 59.5ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 58.6ms
# Speed: 1.5ms preprocess, 58.6ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 58.1ms
# Speed: 1.6ms preprocess, 58.1ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 3 trucks, 61.2ms
# Speed: 1.6ms preprocess, 61.2ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 63.7ms
# Speed: 1.4ms preprocess, 63.7ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 64.5ms
# Speed: 1.3ms preprocess, 64.5ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 59.1ms
# Speed: 1.4ms preprocess, 59.1ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 73.5ms
# Speed: 1.4ms preprocess, 73.5ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 63.2ms
# Speed: 1.2ms preprocess, 63.2ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 63.5ms
# Speed: 1.4ms preprocess, 63.5ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks, 69.3ms
# Speed: 1.2ms preprocess, 69.3ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks, 65.5ms
# Speed: 1.2ms preprocess, 65.5ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks, 58.9ms
# Speed: 1.3ms preprocess, 58.9ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks, 60.3ms
# Speed: 1.2ms preprocess, 60.3ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 58.3ms
# Speed: 1.3ms preprocess, 58.3ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 65.9ms
# Speed: 1.4ms preprocess, 65.9ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 60.4ms
# Speed: 1.4ms preprocess, 60.4ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 3 trucks, 62.9ms
# Speed: 1.3ms preprocess, 62.9ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks,
5ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 3 trucks, 77.6ms
# Speed: 1.4ms preprocess, 77.6ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 77.9ms
# Speed: 1.5ms preprocess, 77.9ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks, 77.3ms
# Speed: 1.6ms preprocess, 77.3ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks, 71.7ms
# Speed: 1.3ms preprocess, 71.7ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 62.2ms
# Speed: 1.2ms preprocess, 62.2ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 65.4ms
# Speed: 1.2ms preprocess, 65.4ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 59.1ms
# Speed: 1.3ms preprocess, 59.1ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 58.7ms
# Speed: 1.3ms preprocess, 58.7ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 72.6ms
# Speed: 1.3ms preprocess, 72.6ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 76.7ms
# Speed: 1.3ms preprocess, 76.7ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 79.4ms
# Speed: 1.3ms preprocess, 79.4ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 71.9ms
# Speed: 1.5ms preprocess, 71.9ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 74.4ms
# Speed: 1.4ms preprocess, 74.4ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 58.8ms
# Speed: 1.5ms preprocess, 58.8ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 61.2ms
# Speed: 1.3ms preprocess, 61.2ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 74.1ms
# Speed: 1.3ms preprocess, 74.1ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 77.1ms
# Speed: 1.2ms preprocess, 77.1ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 69.5ms
# Speed: 1.3ms preprocess, 69.5ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 81.4ms
# Speed: 1.8ms preprocess, 81.4ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 73.0ms
# Speed: 1.5ms preprocess, 73.0ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 64.1ms
# Speed: 1.5ms preprocess, 64.1ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 83.6ms
# Speed: 1.4ms preprocess, 83.6ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 79.2ms
# Speed: 1.3ms preprocess, 79.2ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 79.5ms
# Speed: 1.4ms preprocess, 79.5ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 64.0ms
# Speed: 1.3ms preprocess, 64.0ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 58.9ms
# Speed: 1.3ms preprocess, 58.9ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 79.0ms
# Speed: 1.3ms preprocess, 79.0ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 3 trucks, 78.6ms
# Speed: 1.3ms preprocess, 78.6ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 3 trucks, 75.8ms
# Speed: 1.3ms preprocess, 75.8ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 3 trucks, 62.4ms
# Speed: 1.3ms preprocess, 62.4ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 3 trucks, 73.1ms
# Speed: 1.3ms preprocess, 73.1ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 3 trucks, 59.2ms
# Speed: 1.5ms preprocess, 59.2ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 4 trucks, 78.0ms
# Speed: 1.4ms preprocess, 78.0ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 4 trucks, 79.7ms
# Speed: 1.3ms preprocess, 79.7ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 4 trucks, 65.8ms
# Speed: 1.8ms preprocess, 65.8ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 5 trucks, 79.1ms
# Speed: 1.4ms preprocess, 79.1ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 4 trucks, 75.5ms
# Speed: 1.4ms preprocess, 75.5ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 5 trucks, 77.0ms
# Speed: 1.7ms preprocess, 77.0ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 2 trucks, 77.9ms
# Speed: 1.3ms preprocess, 77.9ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 4 trucks, 74.0ms
# Speed: 1.5ms preprocess, 74.0ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 4 trucks, 62.8ms
# Speed: 1.5ms preprocess, 62.8ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 3 trucks, 57.8ms
# Speed: 1.2ms preprocess, 57.8ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 2 trucks, 67.0ms
# Speed: 1.3ms preprocess, 67.0ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 2 trucks, 62.4ms
# Speed: 1.3ms preprocess, 62.4ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 2 trucks, 64.7ms
# Speed: 1.3ms preprocess, 64.7ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 3 trucks, 65.0ms
# Speed: 1.6ms preprocess, 65.0ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 3 trucks, 64.2ms
# Speed: 1.5ms preprocess, 64.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 63.2ms
# Speed: 1.3ms preprocess, 63.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 4 trucks, 73.7ms
# Speed: 1.3ms preprocess, 73.7ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 4 trucks, 67.3ms
# Speed: 1.4ms preprocess, 67.3ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 60.0ms
# Speed: 1.4ms preprocess, 60.0ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 59.0ms
# Speed: 1.4ms preprocess, 59.0ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 60.7ms
# Speed: 1.4ms preprocess, 60.7ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 62.5ms
# Speed: 1.4ms preprocess, 62.5ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks, 62.4ms
# Speed: 1.3ms preprocess, 62.4ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 62.4ms
# Speed: 1.3ms preprocess, 62.4ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 61.5ms
# Speed: 1.6ms preprocess, 61.5ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 60.5ms
# Speed: 1.3ms preprocess, 60.5ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 59.3ms
# Speed: 1.3ms preprocess, 59.3ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 58.8ms
# Speed: 1.4ms preprocess, 58.8ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 60.7ms
# Speed: 1.4ms preprocess, 60.7ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 60.0ms
# Speed: 1.3ms preprocess, 60.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 60.4ms
# Speed: 1.7ms preprocess, 60.4ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 58.5ms
# Speed: 1.4ms preprocess, 58.5ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 65.1ms
# Speed: 1.3ms preprocess, 65.1ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 56.9ms
# Speed: 1.5ms preprocess, 56.9ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 60.6ms
# Speed: 1.7ms preprocess, 60.6ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 67.8ms
# Speed: 1.4ms preprocess, 67.8ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 62.2ms
# Speed: 1.3ms preprocess, 62.2ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 64.8ms
# Speed: 1.3ms preprocess, 64.8ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 63.8ms
# Speed: 1.4ms preprocess, 63.8ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 72.4ms
# Speed: 1.3ms preprocess, 72.4ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 72.9ms
# Speed: 1.4ms preprocess, 72.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 65.9ms
# Speed: 1.4ms preprocess, 65.9ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 59.1ms
# Speed: 1.3ms preprocess, 59.1ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 61.6ms
# Speed: 1.4ms preprocess, 61.6ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 59.6ms
# Speed: 1.3ms preprocess, 59.6ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 63.4ms
# Speed: 1.3ms preprocess, 63.4ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 58.6ms
# Speed: 1.3ms preprocess, 58.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 63.8ms
# Speed: 1.5ms preprocess, 63.8ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 68.4ms
# Speed: 1.3ms preprocess, 68.4ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 59.0ms
# Speed: 1.5ms preprocess, 59.0ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 60.3ms
# Speed: 1.5ms preprocess, 60.3ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 58.9ms
# Speed: 1.5ms preprocess, 58.9ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 59.1ms
# Speed: 1.3ms preprocess, 59.1ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 59.7ms
# Speed: 1.4ms preprocess, 59.7ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 60.8ms
# Speed: 1.3ms preprocess, 60.8ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 58.0ms
# Speed: 1.4ms preprocess, 58.0ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 60.1ms
# Speed: 1.4ms preprocess, 60.1ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 1 truck, 60.9ms
# Speed: 1.6ms preprocess, 60.9ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 1 truck, 58.8ms
# Speed: 1.2ms preprocess, 58.8ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 67.0ms
# Speed: 1.3ms preprocess, 67.0ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 70.9ms
# Speed: 1.4ms preprocess, 70.9ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 74.0ms
# Speed: 1.3ms preprocess, 74.0ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 73.6ms
# Speed: 1.6ms preprocess, 73.6ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 65.0ms
# Speed: 1.5ms preprocess, 65.0ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 77.7ms
# Speed: 1.3ms preprocess, 77.7ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 76.2ms
# Speed: 1.4ms preprocess, 76.2ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 75.0ms
# Speed: 1.5ms preprocess, 75.0ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 77.2ms
# Speed: 1.6ms preprocess, 77.2ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 63.2ms
# Speed: 1.5ms preprocess, 63.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 60.4ms
# Speed: 1.5ms preprocess, 60.4ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 2 trucks, 63.0ms
# Speed: 1.6ms preprocess, 63.0ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
